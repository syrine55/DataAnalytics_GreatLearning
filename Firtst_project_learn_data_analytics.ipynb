# %%
import pandas as pd
import numpy as np

# %%
battle=pd.read_csv("battles.csv")

# %%
battle
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
battle.head(3)
# Out:
#                           name  year  battle_number             attacker_king  \
# 0   Battle of the Golden Tooth   298              1  Joffrey/Tommen Baratheon
# 1  Battle at the Mummer's Ford   298              2  Joffrey/Tommen Baratheon
# 2           Battle of Riverrun   298              3  Joffrey/Tommen Baratheon
#
#   defender_king attacker_1 attacker_2 attacker_3 attacker_4 defender_1  ...  \
# 0    Robb Stark  Lannister        NaN        NaN        NaN      Tully  ...
# 1    Robb Stark  Lannister        NaN        NaN        NaN  Baratheon  ...
# 2    Robb Stark  Lannister        NaN        NaN        NaN      Tully  ...
#
#   major_death  major_capture  attacker_size defender_size  \
# 0         1.0            0.0        15000.0        4000.0
# 1         1.0            0.0            NaN         120.0
# 2         0.0            1.0        15000.0       10000.0
#
#              attacker_commander             defender_commander  summer  \
# ...

# %%
battle.shape
# Out:
# (38, 25)

# %%
battle['attacker_king'].value_counts()
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64

# %%
battle.rename(columns={'attacker_1':'first_attacker'},inplace=False)
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king first_attacker  \
# 0  Joffrey/Tommen Baratheon                Robb Stark      Lannister
# 1  Joffrey/Tommen Baratheon                Robb Stark      Lannister
# 2  Joffrey/Tommen Baratheon                Robb Stark      Lannister
# 3                Robb Stark  Joffrey/Tommen Baratheon          Stark
# 4                Robb Stark  Joffrey/Tommen Baratheon          Stark
#
#   attacker_2 attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
battle['location'].value_counts()
# Out:
# Riverrun                                3
# Winterfell                              3
# Moat Cailin                             2
# Harrenhal                               2
# Storm's End                             2
# Darry                                   2
# Torrhen's Square                        2
# Deepwood Motte                          2
# Dragonstone                             1
# Stony Shore                             1
# Castle Black                            1
# King's Landing                          1
# Green Fork                              1
# Golden Tooth                            1
# Raventree                               1
# Saltpans                                1
# Seagard                                 1
# Ryamsport, Vinetown, Starfish Harbor    1
# Duskendale                              1
# Red Fork                                1
# Crag                                    1
# Shield Islands                          1
# ...

# %%
battle['attacker_king'].value_counts()
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64

# %%
import seaborn  as sbn
from matplotlib import pyplot as py

# %%
sbn.set(rc={'figure.figsize':(13,5)})
sbn.barplot(x='defender_king',y='defender_size',data=battle, palette='Set3')
# Out:
# <AxesSubplot:xlabel='defender_king', ylabel='defender_size'>

# %%
sbn.countplot(x='defender_king',hue='region',data=battle, palette='Set3')
# Out:
# <AxesSubplot:xlabel='defender_king', ylabel='count'>

# %%
battle.describe()
# Out:
#              year  battle_number  defender_3  defender_4  major_death  \
# count   38.000000      38.000000         0.0         0.0    37.000000
# mean   299.105263      19.500000         NaN         NaN     0.351351
# std      0.689280      11.113055         NaN         NaN     0.483978
# min    298.000000       1.000000         NaN         NaN     0.000000
# 25%    299.000000      10.250000         NaN         NaN     0.000000
# 50%    299.000000      19.500000         NaN         NaN     0.000000
# 75%    300.000000      28.750000         NaN         NaN     1.000000
# max    300.000000      38.000000         NaN         NaN     1.000000
#
#        major_capture  attacker_size  defender_size     summer
# count      37.000000      24.000000      19.000000  37.000000
# mean        0.297297    9942.541667    6428.157895   0.702703
# std         0.463373   20283.092065    6225.182106   0.463373
# min         0.000000      20.000000     100.000000   0.000000
# ...

# %%
sbn.pairplot(battle)
